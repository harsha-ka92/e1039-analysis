// %%
R__LOAD_LIBRARY(hodo_ana)

// %%
gROOT->SetStyle("ATLAS");

// %% [markdown]
// # Plane Efficiency

// %%
hodo_effi* hodo = new hodo_effi();

// %%
// station 1
hodo->reg_det("H1B");
hodo->reg_det("H1T");
hodo->reg_det("H1L");
hodo->reg_det("H1R");
// station 2
hodo->reg_det("H2B");
hodo->reg_det("H2T");
hodo->reg_det("H2R");
hodo->reg_det("H2L");
// station 3
hodo->reg_det("H3B");
hodo->reg_det("H3T");
// station 4
hodo->reg_det("H4B");
hodo->reg_det("H4T");
hodo->reg_det("H4Y1L");
hodo->reg_det("H4Y1R");
hodo->reg_det("H4Y2L");
hodo->reg_det("H4Y2R");

// %%
hodo->ana();

// %%
hodo->print();
