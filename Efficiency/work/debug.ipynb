// %%
R__LOAD_LIBRARY(hodo_ana)

// %%
gROOT->SetStyle("ATLAS");

// %%
using namespace std;

// %% [markdown]
// # Efficiency Plots

// %% [markdown]
// Reconstructed data was used to get the efficiency plots.

// %% [markdown]
// ## Nominal Voltage

// %%
hodo_debug* H1 = new hodo_debug();
H1->reg_det("H4Bu");
H1->reg_det("H4Y1Rr");
H1->reg_det("H4Y1Lr");
H1->reg_det("H4Y2Rr");

// %%
H1->ana();

// %%
H1->print();
